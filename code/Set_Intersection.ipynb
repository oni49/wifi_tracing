# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/Clean_wap_log_20190613.csv")
df.head()
# Out:
#    Unnamed: 0  RSSI  CHANNEL SENSOR         EPOCH       OUI  \
# 0           0     0        1   Pi3B  1.559696e+09  B0:B9:8A
# 1           1     0        1   Pi3B  1.559696e+09  4C:01:43
# 2           2     0        1   Pi3B  1.559696e+09  94:8F:CF
# 3           3     0        1   Pi3B  1.559696e+09  0C:EA:C9
# 4           4     0        1   Pi3B  1.559696e+09  88:96:4E
#
#                                HASH        CO
# 0  0af6b9c7ccb0ca7105303b3cad7ec22f   Netgear
# 1  172b5824dbe65036406783398672bf7a      Eero
# 2  ac31484895c5705d38fc292605778dbc  ArrisGro
# 3  eab56c71ae77fae1653f486aa3b3a93b  ArrisGro
# 4  f4b963655e9bf59f89dcc09396468861  ArrisGro

# %%
sensor1 = set(df.loc[df['SENSOR'] == 'Pi3B']['HASH'])
sensor2 = set(df.loc[df['SENSOR'] == 'oni']['HASH'])

# %%
sensor1.intersection(sensor2)
# Out:
# {'02914bcd7097230ea330925ccf2e1ab5',
#  '03359ffb055105808dbb649839f90c89',
#  '095eb2a8f62bc02f67ca26ef7c87bde2',
#  '099aeb0c4c059d7e2add6db5f8d5208a',
#  '0af6b9c7ccb0ca7105303b3cad7ec22f',
#  '0ec344a6c2da64339c7461b75f82aa1e',
#  '0ff99aaa452fc161fbd250158ed3bd81',
#  '10e0b7b64681bc18a68f0a0125851742',
#  '154d4b983ef91e7d213f35dac7ef0688',
#  '172b5824dbe65036406783398672bf7a',
#  '23fd8d6930877164aa204f4af10cafd9',
#  '246ec6508e6bb55c763d0feb1955207f',
#  '289d8b8e6de57249144876032248d791',
#  '2cb50177ab9cc77cfd873d32df4a5ad3',
#  '2d58738742f4b274aa5d7fb7d02aec47',
#  '2ee36a4b9e7b16eeed714e0495db5d7e',
#  '2efe70dc87c412024ca1bd5727d3edb3',
#  '3275c67a5279c12ac925b4a82914cd8a',
#  '33ffa85df517e9575f9ac4f838b5d8d2',
#  '352050607e18d3d51b3986ebf8511ffc',
#  '3786a1b0a22c329824794615be827694',
#  '38017baaa4b29fa989a0b75931fe5c06',
#  '3d4d759f0563aa6ef4fd8af03138709a',
#  '405ff991b12199d26e626d79a76666b8',
#  '41ccafb42079e3057e093820fa3e896f',
# ...
